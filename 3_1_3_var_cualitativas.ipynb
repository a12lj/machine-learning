# %% [markdown]
# ![](img/logoitqv1.jpg)
#
# ## 01PAO26-26 - Variables cualitativas
#
# ![](img/python_logo.png)
#
#
# *Alysson Guaman*
#
# **Repositorio:** [Github](https://github.com/a12lj/machine-learning.git)

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Bachillerato' 'Master'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Doctorado' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Doctorado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Master' 'Master' 'Master' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Doctorado'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Master'
#  'Grado' 'Master' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Master' 'Master' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Master' 'Master' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Master' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Doctorado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Grado' 'Doctorado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Master' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Master'
#  'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Doctorado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Doctorado' 'Master' 'Secundaria' 'Grado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np

estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia)  # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = ['red', 'blue', 'orange', 'green', 'cyan']  # lista en lugar de set, para garantizar
                                                        # que el orden de los colores coincide
                                                        # siempre con el de 'estudios'
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %% [markdown]
# ### Tarea
#
# Implementar con pandas esta misma información (frecuencias absolutas de `nivel_estudios`, diagrama de barras y diagrama de sectores).

# %%
# Tarea: implementar con pandas esta información
import pandas as pd

serie_estudios = pd.Series(nivel_estudios)

# Frecuencias absolutas con pandas
frecuencia_pd = serie_estudios.value_counts()
display(frecuencia_pd)
# Out:
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
# Diagrama de barras con pandas
frecuencia_pd.plot(kind='bar', ylabel='Frecuencia absoluta', xlabel='Nivel de estudios',
                    title='Diagrama de barras (pandas)', rot=0)
plt.show()

# %%
# Diagrama de sectores con pandas
frecuencia_pd.plot(kind='pie', autopct='%1.2f%%', ylabel='',
                    title='Diagrama de sectores (pandas)')
plt.show()
